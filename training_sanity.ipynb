# %% [markdown]
# %cd /home/jovyan/DISSERTATION
#
# from training.train_meta import train_meta_loop
#
# train_meta_loop()

# %%
# %cd /home/jovyan/DISSERTATION

import sys
sys.path.append('/home/jovyan/DISSERTATION')

# Redirect output to file while showing in notebook
import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    handlers=[
        logging.FileHandler('training.log'),
        logging.StreamHandler(sys.stdout)
    ]
)

from training.train_meta import train_meta_loop

try:
    train_meta_loop()
except Exception as e:
    print(f"Training failed: {e}")
    raise
# Out:
# [Errno 2] No such file or directory: '/home/jovyan/DISSERTATION'
# /home/jovyan/DISSERTATION
# 🚀 Starting meta-training on cuda
# Train trajectories: 12000 | Val trajectories: 1200
# Epoch 1/50: 100%|██████████| 187/187 [01:51<00:00,  1.68it/s, loss=0.0813]
# [Epoch 1] Train Loss: 0.130535
# [Epoch 1] Val Loss:   0.094152
# Epoch 2/50: 100%|██████████| 187/187 [01:40<00:00,  1.87it/s, loss=0.0796]
# [Epoch 2] Train Loss: 0.089607
# [Epoch 2] Val Loss:   0.091790
# Epoch 3/50: 100%|██████████| 187/187 [01:40<00:00,  1.87it/s, loss=0.085]
# [Epoch 3] Train Loss: 0.088240
# [Epoch 3] Val Loss:   0.089699
# Epoch 4/50: 100%|██████████| 187/187 [01:39<00:00,  1.88it/s, loss=0.0861]
# [Epoch 4] Train Loss: 0.087250
# [Epoch 4] Val Loss:   0.091280
# Epoch 5/50: 100%|██████████| 187/187 [01:34<00:00,  1.98it/s, loss=0.0767]
# [Epoch 5] Train Loss: 0.087025
# [Epoch 5] Val Loss:   0.089970
# Epoch 6/50: 100%|██████████| 187/187 [01:34<00:00,  1.97it/s, loss=0.0835]
# ...
