# %%
import sys
import os

# 1. Ensure the project root is in the path so imports work
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

# 2. Import the main function from your new script
#    Make sure the file is saved at evaluation/proximity_analysis.py
from evaluation.proximity_analysis import main

# 3. Run it
if __name__ == "__main__":
    try:
        main()
    except FileNotFoundError as e:
        print(f"❌ Error: {e}")
        print("Did you run the adaptation step first?")
# Out:
# 🔍 Starting Proximity Analysis...
# Training distribution shape: torch.Size([100, 45])
# Computing distances to training manifold...
# ✅ Analysis saved to results/adaptation_with_distances.csv
#
# 📊 Correlation: Distance vs Zero-Shot Error
# (Positive correlation = Farther tasks are harder to predict)
# --------------------------------------------------
# [testA]
#    Correlation: 0.4490
#    Avg Distance: 1.8792
#    Avg MSE:      0.2230
# [testB]
#    Correlation: 0.5295
#    Avg Distance: 3.1506
#    Avg MSE:      0.5855
# [testC]
#    Correlation: 0.5023
#    Avg Distance: 3.5854
#    Avg MSE:      0.8926
